# %%
import pandas as pd

df = pd.read_csv('balance_hist_anon.csv', index_col=0)
df.index.name = 'id'
df
# Out:
# /Users/joe/opt/anaconda3/lib/python3.7/site-packages/numpy/lib/arraysetops.py:472: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   mask |= (ar1 == a)
#          EBIZ_BALANCE_ID               VALID_FROM                 VALID_TO  \
# id
# 0              208724450  2017-04-14 22:24:01.683  2017-04-14 22:26:07.497
# 1              208724451  2017-04-14 22:24:01.683  2017-04-14 22:26:07.497
# 2              208724452  2017-04-14 22:24:01.683  2017-04-14 22:26:07.497
# 3              208724453  2017-04-14 22:24:01.683  2017-04-14 22:26:07.497
# 4              208724454  2017-04-14 22:24:01.683  2017-04-14 22:26:07.497
# ...                  ...                      ...                      ...
# 6427311        538436575  2020-07-31 14:28:51.530  2020-10-26 11:45:54.447
# 6427312        538436694  2020-07-31 14:28:51.530  2020-10-26 11:45:54.447
# ...

# %%
df['CURRENCY'].unique()
# Out:
# array(['HUF', 'EUR', 'USD', 'RON', 'PLN', 'CZK', 'GBP', 'CHF', 'BGN',
#        'HRK', 'RSD', 'SEK'], dtype=object)

# %% [markdown]
# 2 reasons why only small part is used:
# 1. smaller dataset - easier testing
# 2. number of rows can be increased instead of resetting offset

# %%
df.head(20000).to_csv('data/balance.csv', index=True)

# %% [markdown]
# Exchange rates

# %%
exchange_rate_df = pd.read_csv('eurofxref-hist.csv', index_col=0)
exchange_rate_df
# Out:
#                USD     JPY     BGN      CYP     CZK     DKK      EEK      GBP  \
# Date
# 2020-12-09  1.2109  126.05  1.9558      NaN  26.239  7.4429      NaN  0.90000
# 2020-12-08  1.2114  126.18  1.9558      NaN  26.398  7.4436      NaN  0.91143
# 2020-12-07  1.2128  126.30  1.9558      NaN  26.482  7.4433      NaN  0.91215
# 2020-12-04  1.2159  126.44  1.9558      NaN  26.518  7.4429      NaN  0.90282
# 2020-12-03  1.2151  126.49  1.9558      NaN  26.420  7.4439      NaN  0.90358
# ...            ...     ...     ...      ...     ...     ...      ...      ...
# 1999-01-08  1.1659  130.09     NaN  0.58187  34.938  7.4433  15.6466  0.70940
# 1999-01-07  1.1632  129.43     NaN  0.58187  34.886  7.4431  15.6466  0.70585
# 1999-01-06  1.1743  131.42     NaN  0.58200  34.850  7.4452  15.6466  0.70760
# 1999-01-05  1.1790  130.96     NaN  0.58230  34.917  7.4495  15.6466  0.71220
# 1999-01-04  1.1789  133.73     NaN  0.58231  35.107  7.4501  15.6466  0.71110
#
# ...

# %%
exchange_rate_df = pd.read_csv('eurofxref-hist.csv', index_col=0)
exchange_rate_df = exchange_rate_df[['HUF', 'USD', 'GBP', 'RON', 'CHF', 'PLN', 'CZK','BGN', 'HRK', 'SEK']]
exchange_rate_df = exchange_rate_df.sort_index()
exchange_rate_df = exchange_rate_df.loc['2017-01-01':'2020-12-10']
exchange_rate_df.to_csv('exchange.csv', index=True)
exchange_rate_df
# Out:
#                HUF     USD      GBP     RON     CHF     PLN     CZK     BGN  \
# Date
# 2017-01-02  309.45  1.0465  0.85140  4.5390  1.0711  4.4123  27.021  1.9558
# 2017-01-03  308.94  1.0385  0.84565  4.5228  1.0702  4.3934  27.020  1.9558
# 2017-01-04  308.35  1.0437  0.84945  4.5086  1.0707  4.3778  27.021  1.9558
# 2017-01-05  308.28  1.0501  0.85440  4.5065  1.0704  4.3680  27.021  1.9558
# 2017-01-06  307.24  1.0589  0.85648  4.5013  1.0725  4.3552  27.021  1.9558
# ...            ...     ...      ...     ...     ...     ...     ...     ...
# 2020-12-03  357.63  1.2151  0.90358  4.8730  1.0831  4.4733  26.420  1.9558
# 2020-12-04  358.57  1.2159  0.90282  4.8725  1.0822  4.4769  26.518  1.9558
# 2020-12-07  359.49  1.2128  0.91215  4.8735  1.0802  4.4670  26.482  1.9558
# 2020-12-08  360.10  1.2114  0.91143  4.8728  1.0781  4.4663  26.398  1.9558
# 2020-12-09  356.64  1.2109  0.90000  4.8685  1.0764  4.4246  26.239  1.9558
#
#                HRK      SEK
# Date
# ...

# %%
exchange_rate_df.loc['2018-11-20']
# Out:
# HUF    321.25000
# USD      1.14210
# GBP      0.88908
# RON      4.66730
# CHF      1.13280
# PLN      4.31770
# CZK     26.03200
# BGN      1.95580
# HRK      7.42770
# SEK     10.31330
# Name: 2018-11-20, dtype: float64
